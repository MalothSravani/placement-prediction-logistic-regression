# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.linear_model import LogisticRegression
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["cgpa"],df["iq"],c=df["placement"])

# %%
x = df.iloc[:,0:2]

# %%
y = df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
x.shape
# Out:
# (100, 2)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 72   7.3  116.0
# 46   5.3  114.0
# 19   5.2  132.0
# 12   5.4  139.0
# 47   5.2  161.0
# ..   ...    ...
# 11   6.9  138.0
# 81   5.4  107.0
# 71   6.1  132.0
# 36   5.7  140.0
# 85   5.8  166.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 46   5.3  114.0
# 15   5.1  176.0
# 32   7.0  139.0
# 92   5.2  110.0
# 95   4.3  200.0
# 77   7.3   50.0
# 88   4.4  149.0
# 9    5.1   66.0
# 89   4.9  151.0
# 90   7.3   86.0

# %%
y_train
# Out:
# 72    1
# 46    0
# 19    0
# 12    0
# 47    0
#      ..
# 11    1
# 81    0
# 71    1
# 36    0
# 85    1
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.10596816, -0.2780035 ],
#        [-0.6972408 , -0.33034726],
#        [-0.78740125,  0.14074654],
#        [-0.60708035,  0.32394969],
#        [-0.78740125,  0.899731  ],
#        [ 0.83548682,  1.26613729],
#        [ 0.83548682, -0.38269101],
#        [ 0.56500547,  1.44934043],
#        [-1.59884528,  1.92043423],
#        [-1.32836393,  0.50715283],
#        [ 1.37644951,  0.03605903],
#        [ 0.02404279, -1.19401922],
#        [ 1.28628906,  0.08840279],
#        [-1.23820349, -1.95300368],
#        [ 0.47484503,  0.29777781],
#        [ 1.37644951, -0.9846442 ],
#        [ 0.83548682,  0.32394969],
#        [-0.96772214, -0.22565975],
#        [ 0.65516592, -0.38269101],
#        [ 0.83548682, -1.63894115],
#        [-1.05788259, -0.17331599],
#        [ 0.47484503, -0.17331599],
#        [ 0.02404279, -0.61823791],
#        [ 0.20436368,  0.00988715],
#        [-0.87756169, -1.58659739],
#        [ 1.28628906,  0.82121536],
#        [-0.33659901,  1.10910602],
#        [-1.86932662, -1.35105049],
#        [ 1.28628906, -1.71745678],
#        [ 0.65516592,  0.37629344],
#        [ 0.02404279, -1.61276927],
#        [-1.05788259, -1.71745678],
#        [-1.50868483,  0.58566846],
#        [-1.23820349, -0.14714411],
#        [ 0.38468458,  0.87355912],
#        [ 1.5567704 , -0.33034726],
#        [-0.15627811, -0.53972228],
#        [-0.06611766,  0.58566846],
#        [-1.05788259,  0.63801222],
#        [ 0.02404279,  0.76887161],
#        [-0.06611766, -1.58659739],
#        [ 1.10596816, -1.06315983],
#        [-0.87756169,  1.29230916],
#        [ 0.20436368,  0.03605903],
#        [-1.23820349, -1.03698796],
#        [ 0.29452413,  0.37629344],
#        [ 0.83548682,  1.89426235],
#        [ 0.65516592, -0.95847232],
#        [ 1.10596816,  0.27160593],
#        [-0.06611766, -2.13620682],
#        [-0.24643856,  0.40246532],
#        [ 0.38468458, -0.95847232],
#        [-1.95948707, -0.46120665],
#        [ 0.11420323, -0.35651913],
#        [-0.06611766, -0.06862848],
#        [ 1.19612861,  0.14074654],
#        [-0.78740125,  2.5485593 ],
#        [ 0.65516592, -0.09480036],
#        [-1.05788259,  0.1930903 ],
#        [-0.60708035,  0.21926218],
#        [-1.14804304,  1.10910602],
#        [-1.05788259,  1.81574672],
#        [-1.14804304,  0.95207475],
#        [-0.87756169,  0.03605903],
#        [-0.96772214, -1.66511302],
#        [-1.14804304,  0.37629344],
#        [ 0.56500547,  0.71652785],
#        [-0.06611766, -0.64440979],
#        [ 1.7370913 , -1.24636298],
#        [ 2.18789354, -0.17331599],
#        [ 1.82725175,  1.03059039],
#        [ 0.74532637,  0.32394969],
#        [ 0.29452413, -0.2780035 ],
#        [ 1.10596816, -2.00534743],
#        [ 0.38468458,  0.08840279],
#        [ 2.00757264,  1.08293414],
#        [-1.05788259,  0.74269973],
#        [-0.78740125, -0.95847232],
#        [-2.32012886,  2.7841062 ],
#        [-0.33659901,  0.4286372 ],
#        [-0.6972408 , -0.14714411],
#        [ 0.92564727,  0.63801222],
#        [-0.78740125, -0.43503477],
#        [ 0.74532637, -0.80144106],
#        [ 1.82725175,  0.58566846],
#        [ 0.74532637,  0.29777781],
#        [-0.60708035, -0.5135504 ],
#        [ 0.02404279,  0.14074654],
#        [-0.33659901,  0.35012156],
#        [-0.24643856,  1.03059039]])

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-1.50868483, -2.21472246],
#        [-1.86932662, -0.69675355],
#        [ 0.38468458, -2.34558185],
#        [ 0.92564727, -2.05769119],
#        [-0.96772214, -0.93230045],
#        [-0.33659901,  0.14074654],
#        [-0.60708035, -0.33034726],
#        [-2.50044976,  1.47551231],
#        [ 0.20436368, -0.61823791],
#        [-1.14804304, -0.38269101]])

# %%
clf = LogisticRegression()

# %%
print(type(clf))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>

# %%
clf.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 96    0
# 18    0
# 82    1
# 5     1
# 25    0
# 87    1
# 41    0
# 17    0
# 98    1
# 59    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
# %pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (0.25.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.18.0)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.5.1)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.9.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (3.11.1)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=9 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\srava\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.plotting import plot_decision_regions

# %%
import mlxtend
print(mlxtend.__version__)
# Out:
# 0.25.0

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open("model.pkl","wb"))
